# %%
import pandas as pd
import numpy as np
import requests
from bs4 import BeautifulSoup

# %%
df=pd.read_csv('http://web.mta.info/developers/data/nyct/turnstile/turnstile_221008.txt',sep=',')

# %%
df
# Out:
#           C/A  UNIT       SCP        STATION LINENAME DIVISION        DATE  \
# 0        A002  R051  02-00-00          59 ST  NQR456W      BMT  10/01/2022
# 1        A002  R051  02-00-00          59 ST  NQR456W      BMT  10/01/2022
# 2        A002  R051  02-00-00          59 ST  NQR456W      BMT  10/01/2022
# 3        A002  R051  02-00-00          59 ST  NQR456W      BMT  10/01/2022
# 4        A002  R051  02-00-00          59 ST  NQR456W      BMT  10/01/2022
# ...       ...   ...       ...            ...      ...      ...         ...
# 210998  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  10/07/2022
# 210999  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  10/07/2022
# 211000  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  10/07/2022
# 211001  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  10/07/2022
# 211002  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  10/07/2022
#
#             TIME     DESC  ENTRIES  \
# ...

# %%
url = "http://web.mta.info/developers/turnstile.html"
res=requests.get(url)
page=BeautifulSoup(res.content)
mydivs = page.find_all("div", {"class": "span-84 last"})
links_all=[]
for div in mydivs:
    links=div.findAll('a')
links
for a in links:
    links_all.append("http://web.mta.info/developers/"+a['href'])
links_all
# Out:
# ['http://web.mta.info/developers/data/nyct/turnstile/turnstile_221008.txt',
#  'http://web.mta.info/developers/data/nyct/turnstile/turnstile_221001.txt',
#  'http://web.mta.info/developers/data/nyct/turnstile/turnstile_220924.txt',
#  'http://web.mta.info/developers/data/nyct/turnstile/turnstile_220917.txt',
#  'http://web.mta.info/developers/data/nyct/turnstile/turnstile_220910.txt',
#  'http://web.mta.info/developers/data/nyct/turnstile/turnstile_220903.txt',
#  'http://web.mta.info/developers/data/nyct/turnstile/turnstile_220827.txt',
#  'http://web.mta.info/developers/data/nyct/turnstile/turnstile_220820.txt',
#  'http://web.mta.info/developers/data/nyct/turnstile/turnstile_220813.txt',
#  'http://web.mta.info/developers/data/nyct/turnstile/turnstile_220806.txt',
#  'http://web.mta.info/developers/data/nyct/turnstile/turnstile_220730.txt',
#  'http://web.mta.info/developers/data/nyct/turnstile/turnstile_220723.txt',
# ...
